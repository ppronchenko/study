# %% [raw]
# Загрузить файл wines_data.csv
# Рассчитать и визуализировать корреляции для переменных данного датасета
# Визуализировать взаимосвязи между 3-4 переменными
# Рассчитать t-test статистики для 3-4 переменных

# %%
import pandas as pd
import statistics as st
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
sns.set(font_scale=1.5)
from scipy import stats
from scipy.stats import kurtosis
from scipy.stats import skew

# %%
wine = pd.read_csv('wine_data.csv')

# %%
wine.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
# Class                           178 non-null int64
# Alcohol                         178 non-null float64
# Malic acid                      178 non-null float64
# Ash                             178 non-null float64
# Alcalinity of ash               178 non-null float64
# Magnesium                       178 non-null int64
# Total phenols                   178 non-null float64
# Flavanoids                      178 non-null float64
# Nonflavanoid phenols            178 non-null float64
# Proanthocyanins                 178 non-null float64
# Color intensity                 178 non-null float64
# Hue                             178 non-null float64
# OD280/OD315 of diluted wines    178 non-null float64
# Proline                         178 non-null int64
# dtypes: float64(11), int64(3)
# memory usage: 19.5 KB

# %%
wine.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
corr = wine.corr()

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(corr, annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
g = sns.pairplot(wine, vars=['Alcohol', 'Proline'],
                 kind='scatter')
g.fig.set_size_inches(15,15)

# %%
g = sns.pairplot(wine, vars=['Class', 'Flavanoids'],
                 kind='scatter')
g.fig.set_size_inches(15,15)

# %%
g = sns.pairplot(wine, vars=['Alcohol', 'Color intensity'],
                 kind='scatter')
g.fig.set_size_inches(15,15)

# %%
wine['Class'].value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Class, dtype: int64

# %%
wine_mean = wine.groupby('Class').mean()
wine_mean
# Out:
#          Alcohol  Malic acid       Ash  Alcalinity of ash   Magnesium  \
# Class
# 1      13.744746    2.010678  2.455593          17.037288  106.338983
# 2      12.278732    1.932676  2.244789          20.238028   94.549296
# 3      13.153750    3.333750  2.437083          21.416667   99.312500
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# Class
# 1           2.840169    2.982373              0.290000         1.899322
# 2           2.258873    2.080845              0.363662         1.630282
# 3           1.678750    0.781458              0.447500         1.153542
#
#        Color intensity       Hue  OD280/OD315 of diluted wines      Proline
# Class
# 1             5.528305  1.062034                      3.157797  1115.711864
# 2             3.086620  1.056282                      2.785352   519.507042
# 3             7.396250  0.682708                      1.683542   629.895833

# %%
first = wine[wine['Class']==1]
second = wine[wine['Class']==2]

# %%
stats.ttest_ind(first['Alcohol'], second['Alcohol'])
# Out:
# Ttest_indResult(statistic=16.478551495156523, pvalue=1.9551698789379755e-33)

# %%
stats.ttest_ind(first['Malic acid'], second['Malic acid'])
# Out:
# Ttest_indResult(statistic=0.5017165419259085, pvalue=0.6167288052204474)

# %%
stats.ttest_ind(first['Hue'], second['Hue'])
# Out:
# Ttest_indResult(statistic=0.19284236940182017, pvalue=0.8473880636422892)
