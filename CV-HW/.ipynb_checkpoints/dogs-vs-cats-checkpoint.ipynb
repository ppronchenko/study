# %% [markdown]
# # Dogs vs. Cats

# %%
# Выводим доступные девайсы для tensorflow

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4985463911244876852
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 753719106209729554
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 8236028348768763520
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3379167232
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11173731878656461160
# physical_device_desc: "device: 0, name: GeForce GTX 1050 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %%
# Тест на доступ к GPU

# %%
#confirm TensorFlow sees the GPU
from tensorflow.python.client import device_lib
assert 'GPU' in str(device_lib.list_local_devices())

# confirm Keras sees the GPU
from keras import backend
assert len(backend.tensorflow_backend._get_available_gpus()) > 0

# confirm PyTorch sees the GPU
#from torch import cuda
#assert cuda.is_available()
#assert cuda.device_count() > 0
#print(cuda.get_device_name(cuda.current_device()))
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %%
IMG_SIZE = (224, 224)  # размер входного изображения сети

# %% [markdown]
# ## Функции загрузки данных

# %%
import re
from random import shuffle
from glob import glob

train_files = glob('/home/pavel/HomeWork/train/*.jpg')
test_files = glob('/home/pavel/HomeWork/test/*.jpg')

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = load_img(path, target_size=target_size)  # загрузка и масштабирование изображения
    array = img_to_array(img)
    return preprocess_input(array)  # предобработка для VGG16

def is_dog(path):
    return re.match('.*dog\.\d', path) is not None

# генератор для последовательного чтения обучающих данных с диска
def fit_generator(files, batch_size=32):
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if re.match('.*/dog\.\d', path) else 0. for path in files[i:j]])
            yield (x, y)
            
            

# генератор последовательного чтения тестовых данных с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %% [markdown]
# ## Визуализируем примеры для обучения

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(20, 20))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(i // 5 + 1, 5, i)
    plt.imshow(plt.imread(path));
    subplot.set_title('%s' % path.split('/')[-1]);

# %% [markdown]
# ## Загружаем предобученную модель

# %%
# base_model -  объект класса keras.models.Model (Functional Model)
base_model = VGG16(include_top = False,
                   weights = 'imagenet',
                   input_shape = (IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False

# %%
base_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ## Добавляем полносвязный слой

# %%
from keras.layers.normalization import BatchNormalization

# %% [markdown]
# #### Модель не сходилась при заданных параметрах в ноутбуке. Добавим еще один полносвязный слой, слой с batch нормализацией и изменим регуляризацию с l1 на l2. Пробовал с доп. слоями полносвязным и дропаут - но модель плохо сходилась

# %%
x = base_model.layers[-5].output
x = keras.layers.BatchNormalization(axis=1)(x)
x = keras.layers.Flatten()(x)
#x = keras.layers.Dense(32, 
#                activation='relu')(x)
#x = keras.layers.Dropout(0.5)(x)
x = keras.layers.Dense(32, 
                activation='relu')(x)
x = keras.layers.Dense(1,  # один выход
                activation='sigmoid',  # функция активации  
                kernel_regularizer=keras.regularizers.l2(1e-7)
                      )(x)
model = Model(inputs=base_model.input, outputs=x)

# %% [markdown]
# ## Выводим архитектуру модели

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 512)       56
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                3211296
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 10,846,649
# Trainable params: 3,211,357
# Non-trainable params: 7,635,292
# _________________________________________________________________

# %% [markdown]
# ## Компилируем модель и запускаем обучение

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss
              metrics=['accuracy'])

# %%
shuffle(train_files)  # перемешиваем обучающую выборку

train_val_split = 100  # число изображений в валидационной выборке

validation_data = next(fit_generator(train_files[:train_val_split], train_val_split))

# запускаем процесс обучения
model.fit_generator(fit_generator(train_files[train_val_split:]),  # данные читаем функцией-генератором
        steps_per_epoch=10,  # число вызовов генератора за эпоху
        epochs=30,  # число эпох обучения
        validation_data=validation_data)
# Out:
# Epoch 1/30
# 10/10 [==============================] - 11s 1s/step - loss: 0.1288 - acc: 0.9656 - val_loss: 0.5202 - val_acc: 0.9700
# Epoch 2/30
# 10/10 [==============================] - 11s 1s/step - loss: 0.1896 - acc: 0.9469 - val_loss: 0.5266 - val_acc: 0.9700
# Epoch 3/30
# 10/10 [==============================] - 10s 986ms/step - loss: 0.1679 - acc: 0.9563 - val_loss: 0.5006 - val_acc: 0.9500
# Epoch 4/30
# 10/10 [==============================] - 11s 1s/step - loss: 0.1246 - acc: 0.9531 - val_loss: 0.5091 - val_acc: 0.9600
# Epoch 5/30
# 10/10 [==============================] - 11s 1s/step - loss: 0.0878 - acc: 0.9719 - val_loss: 0.5139 - val_acc: 0.9700
# Epoch 6/30
# 10/10 [==============================] - 10s 1s/step - loss: 0.1511 - acc: 0.9719 - val_loss: 0.5249 - val_acc: 0.9600
# Epoch 7/30
# 10/10 [==============================] - 10s 1s/step - loss: 0.1177 - acc: 0.9625 - val_loss: 0.5282 - val_acc: 0.9500
# Epoch 8/30
# 10/10 [==============================] - 11s 1s/step - loss: 0.1307 - acc: 0.9563 - val_loss: 0.5245 - val_acc: 0.9600
# Epoch 9/30
# 10/10 [==============================] - 10s 1s/step - loss: 0.1336 - acc: 0.9531 - val_loss: 0.5280 - val_acc: 0.9600
# Epoch 10/30
# 10/10 [==============================] - 11s 1s/step - loss: 0.1790 - acc: 0.9594 - val_loss: 0.5127 - val_acc: 0.9300
# Epoch 11/30
# 10/10 [==============================] - 11s 1s/step - loss: 0.1197 - acc: 0.9469 - val_loss: 0.5072 - val_acc: 0.9600
# Epoch 12/30
# 10/10 [==============================] - 11s 1s/step - loss: 0.0761 - acc: 0.9812 - val_loss: 0.5022 - val_acc: 0.9400
# Epoch 13/30
# 10/10 [==============================] - 11s 1s/step - loss: 0.1588 - acc: 0.9469 - val_loss: 0.4492 - val_acc: 0.9500
# Epoch 14/30
# 10/10 [==============================] - 4s 438ms/step - loss: 0.1000 - acc: 0.9656 - val_loss: 0.4993 - val_acc: 0.9500
# Epoch 15/30
# 10/10 [==============================] - 4s 425ms/step - loss: 0.0861 - acc: 0.9656 - val_loss: 0.5229 - val_acc: 0.9400
# Epoch 16/30
# 10/10 [==============================] - 4s 436ms/step - loss: 0.1215 - acc: 0.9625 - val_loss: 0.5454 - val_acc: 0.9500
# Epoch 17/30
# 10/10 [==============================] - 4s 431ms/step - loss: 0.1012 - acc: 0.9656 - val_loss: 0.5155 - val_acc: 0.9300
# Epoch 18/30
# 10/10 [==============================] - 4s 428ms/step - loss: 0.1230 - acc: 0.9625 - val_loss: 0.4947 - val_acc: 0.9500
# Epoch 19/30
# 10/10 [==============================] - 4s 429ms/step - loss: 0.1163 - acc: 0.9625 - val_loss: 0.5212 - val_acc: 0.9300
# Epoch 20/30
# 10/10 [==============================] - 4s 429ms/step - loss: 0.2041 - acc: 0.9313 - val_loss: 0.5211 - val_acc: 0.9100
# Epoch 21/30
# 10/10 [==============================] - 4s 432ms/step - loss: 0.1070 - acc: 0.9625 - val_loss: 0.5422 - val_acc: 0.9300
# Epoch 22/30
# 10/10 [==============================] - 4s 431ms/step - loss: 0.1111 - acc: 0.9750 - val_loss: 0.5287 - val_acc: 0.9100
# Epoch 23/30
# 10/10 [==============================] - 4s 437ms/step - loss: 0.2018 - acc: 0.9375 - val_loss: 0.5323 - val_acc: 0.9300
# Epoch 24/30
# 10/10 [==============================] - 4s 429ms/step - loss: 0.2851 - acc: 0.9500 - val_loss: 0.5047 - val_acc: 0.9300
# Epoch 25/30
# 10/10 [==============================] - 4s 436ms/step - loss: 0.0920 - acc: 0.9594 - val_loss: 0.5130 - val_acc: 0.9300
# Epoch 26/30
# 10/10 [==============================] - 4s 432ms/step - loss: 0.1562 - acc: 0.9469 - val_loss: 0.5334 - val_acc: 0.9200
# Epoch 27/30
# 10/10 [==============================] - 4s 432ms/step - loss: 0.1361 - acc: 0.9625 - val_loss: 0.5386 - val_acc: 0.9100
# Epoch 28/30
# 10/10 [==============================] - 4s 431ms/step - loss: 0.1501 - acc: 0.9469 - val_loss: 0.4981 - val_acc: 0.9300
# Epoch 29/30
# 10/10 [==============================] - 4s 429ms/step - loss: 0.0665 - acc: 0.9656 - val_loss: 0.4800 - val_acc: 0.9500
# Epoch 30/30
# 10/10 [==============================] - 4s 429ms/step - loss: 0.1373 - acc: 0.9656 - val_loss: 0.5660 - val_acc: 0.9300

# %%
### Модель сошлась за 60 эпох (обучение запускал 2 раза по 30 эпох). Получено нужное качество loss и accuracy

# %%
model.save('cats-dogs-vgg16.hdf5')

# %% [markdown]
# ## Предсказания на проверочной выборке

# %%
pred = model.predict_generator(predict_generator(test_files), len(test_files), max_queue_size=500)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(20, 20))
for i, (path, score) in enumerate(zip(test_files[80:][:10], pred[80:][:10]), 1):
    subplot = fig.add_subplot(i // 5 + 1, 5, i)
    plt.imshow(plt.imread(path));
    subplot.set_title('%.3f' % score);

# %% [markdown]
# ## Готовим данные для сабмита

# %%
with open('submit.txt', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, pred):
        dst.write('%s,%f\n' % (re.search('(\d+)', path).group(0), score))

# %% [markdown]
# ## На kaggle LogLoss = 0.20662

# %% [markdown]
# <img src="submit-cats-dogs.png" style="max-width: 680px; display: inline" />
